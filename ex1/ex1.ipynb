# %% [markdown]
# ## Excercise - 1 - Linear regression with one variable

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Plotting the data

# %%
import os;
path = os.getcwd() + '/data/ex1data1.txt';
data = pd.read_csv(path, header=None, names=['Population', 'Profit']);
data.head(n=5) # List first 5 rows from the dataset
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe() # describe the dataset properties
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
ax = data.plot(kind='scatter', x='Population', y='Profit', figsize=(12, 8))
# ax.xaxis.grid(True, linestyle='-', linewidth=0.25)
# ax.yaxis.grid(True, linestyle='-', linewidth=0.25)
# Don't allow the axis to be on top of your data
ax.set_axisbelow(True)

# Turn on the minor TICKS, which are required for the minor GRID
ax.minorticks_on()

# https://matplotlib.org/gallery/lines_bars_and_markers/linestyles.html
ls = (0, (3, 1, 1, 1, 1, 1))

# Customize the major grid
ax.grid(which='major', linestyle='-', linewidth='0.3', color='red')
# Customize the minor grid
ax.grid(which='minor', linestyle=ls, linewidth='0.2', color='blue')
# Turn off the display of all ticks.
ax.tick_params(which='both') # turn off bottom ticks

# %% [markdown]
# ### Gradient Descent

# %%
data.insert(0, 'Ones', 1)

# %%
data.head()
# Out:
#    Ones  Population   Profit
# 0     1      6.1101  17.5920
# 1     1      5.5277   9.1302
# 2     1      8.5186  13.6620
# 3     1      7.0032  11.8540
# 4     1      5.8598   6.8233

# %%
cols = data.shape[1]; # read only no. of columns
X = data.iloc[:,0:cols-1];
y = data.iloc[:, cols-1:cols];

# %%
# TEST CASE for computeCost function
# computeCost( [1 2; 1 3; 1 4; 1 5], [7;6;5;4], [0.1;0.2] )
_X = np.matrix([[1, 2],[1, 3], [1, 4], [1, 5]]);
_y = np.matrix([7, 6, 5, 4]);
_theta = np.matrix([[0.1], [0.2]]);
print('X = ', _X.shape);
print('y = ', _y.shape);
print('theta = ', len(_theta));

J = computeCost(_X, _y, _theta);
J
# Out:
# X =  (4, 2)
# y =  (1, 4)
# theta =  2
# 46.78

# %%
def computeCost(X, y, theta):
    m = len(X);
    # print('m = %d' %m);
    h = X * theta; # (2 X 4) * (4 X 1)
    squ_Err = np.power((h - y), 2);
    sumSq_Err = np.sum(squ_Err);
    J = (1/(2 * m)) * sumSq_Err;
    return J;

# %%
theta = np.zeros(shape=(2, 1));

# %%
J = computeCost(X, y, theta);
J
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-f9b24b1e7700> in <module>()
# ----> 1 J = computeCost(X, y, theta);
#       2 J
#
# <ipython-input-96-58945c1ed08d> in computeCost(X, y, theta)
#       2     m = len(X);
#       3     # print('m = %d' %m);
# ----> 4     h = X * theta.T; # (2 X 4) * (4 X 1)
#       5     squ_Err = np.power((h - y), 2);
#       6     sumSq_Err = np.sum(squ_Err);
#
# ~/development/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1255     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    1256
# -> 1257         other = _align_method_FRAME(self, other, axis)
#    1258
#    1259         if isinstance(other, ABCDataFrame):  # Another DataFrame
#
# ~/development/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in _align_method_FRAME(left, right, axis)
#    1178                        "must be {req_shape}: given {given_shape}"
#    1179                        ).format(req_shape=left.shape, given_shape=right.shape)
# -> 1180                 raise ValueError(msg)
#    1181
#    1182             right = left._constructor(right, index=left.index,
#
# ValueError: Unable to coerce to DataFrame, shape must be (97, 2): given (1, 2)

# %%
iteration = 1500;
alpha = 0.01;

# %%
def gradientDescent(X, y, theta, alpha, num_iters):
    m = len(X)
    J_history = np.zeros(shape=(num_iters, 1))
    tmpTheta = np.matrix(np.zeros(shape=theta.shape))
    parameters = int(theta.ravel().shape[1])
    print(parameters)
    for i in range(num_iters):
        hs = (X * theta.T) - y
        for j in range(parameters):
            sumPred = alpha * (1/m) * (np.sum(hs * X[:, j]))
            tmpTheta[0, j] = theta[0, j] - sumPred
            # print(tmpTheta)
            # theta[j] = tmpTheta
            # print(theta[j])
            #print(np.matrix(theta))
        theta = tmpTheta     
        J_history[i] = computeCost(X, y, theta)    
    return theta, J_history

# %%
theta, J_hist = gradientDescent(np.matrix([[1, 5], [1, 2], [1, 4], [1, 5]]),
                                 np.matrix([[1, 6, 4, 2]]),
                                 np.matrix([[0, 0]]), 0.01, 5);
theta
# Out:
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-ab1053b2b5d0> in <module>()
#       1 theta, J_hist = gradientDescent(np.matrix([[1, 5], [1, 2], [1, 4], [1, 5]]),
#       2                                  np.matrix([[1, 6, 4, 2]]),
# ----> 3                                  np.matrix([[0, 0]]), 0.01, 5);
#       4 theta
#
# <ipython-input-88-940c5c92d910> in gradientDescent(X, y, theta, alpha, num_iters)
#      15             #print(np.matrix(theta))
#      16         theta = tmpTheta
# ---> 17         J_history[i] = computeCost(X, y, theta)
#      18     return theta, J_history
#
# <ipython-input-6-f76e019295ba> in computeCost(X, y, theta)
#       2     m = len(X);
#       3     # print('m = %d' %m);
# ----> 4     h = np.dot(X, theta); # (2 X 4) * (4 X 1)
#       5     squ_Err = np.power((h - y), 2);
#       6     sumSq_Err = np.sum(squ_Err);
#
# ValueError: shapes (4,2) and (1,2) not aligned: 2 (dim 1) != 1 (dim 0)
